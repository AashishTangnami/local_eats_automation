# %%
##information
info_data = 'welcome to the information '

## merchant info
tax = '13'
order_prep_time = '30 Mins'
delivery_distance = '15'
timezone = 'America/New_York'

food_category = {
    {
    'Category Name' : 'Buy 1 Get 1 Free',
    'Category Desc' : ''
    },
    {
        'Category Name' : 'Chef Favorites',
     'Category Desc' : ''
     },
    {
        'Category Name' : 'Picked For You',
     'Category Desc' : ''
     },
    {
        'Category Name' : 'Create Your Own Masterpiece',
     'Category Desc' : ''}
}

addon_cateogry = {
    'Pick Your Studio Crust',
    'Spread Your Sauce',
    'Choose Your Cheese',
    'Load Your Toppings',
    'Add Your Protein',
    'Specialty Toppings'

}

addon_item_value = {
    'Addon Category Name' : 'Pick Your Studio Crust',
    'Addon Items' : {'Traditional',
    'Firecracker',
    'Gluten Free Crust',
    'Cauliflower Crust (GF)',
    'Whoel Grain & Flax Seed',
    'Rosemary Herb Crust'
    }
}

addon_item_2 = {
    'Addon Category Name' : 'Spread Your Sauce',
    'Addon Items' : {
    'Tomato Blend',
    'Chipotle Tomato Blend',
    'Smokey BBQ ',
    'Spicy Buffalo',
    'Basil Pesto',
    'Garlic Alfredo',
    'Extra Virgin Olive Oil',
    'Butter Chicken',
    'No Sauce'
    }
}

addon_item_3 = {
    'Addon Category Name' : 'Choose Your Cheese',
    'Addon Items' : {
    'Freshly Grated Mozzarella',
    'Extra Mozzarella',
    'Vegan Cheese',
    'No Cheese'
    }
}

addon_item_4 = {
    'Addon Category Name' : 'Load Your Toppings',
    'Add on item' : {
    'Chopped Garlic',
    'Kale',
    'Spinach',
    'Roma Tomatoes',
    'Grape Tomatoes',
    'Black Olives',
    'Green Olives',
    'Sundried Tomatoes',
    'Artichoke',
    'Raw Mushrooms',
    'Roasted Mushrooms',
    'Red Onions',
    'Zucchini',
    'Chipolte Roasted Pineapples',
    'Pineapples',
    'Garlic Roasted Broccoli',
    'Broccoli',
    'Green Peppers',
    'Jalapenos',
    'Banana Peppers',
    'Cranberries',
    'Sliced Almonds',
    'Caramalized Onions',
    'Chipotle Roasted Corn'
    }
}

addon_item_5 = {
    'Addon Cateory Name' : 'Add Your Protein',
    'Add on items ' :{'Pepperoni',
    'Ham',
    'Buffalo chicken',
    'Grilled Chicken',
    'Chorizo Sausage',
    'Italian Sausage',
    'Bacon Crumble',
    'Beef Crumble'
    }
}

addon_item_6 = {
    'Addon Category Name' : 'Specialty Toppings',
    'Add on items' : {
    'Plant Based Chicken',
    'Plant Based Meatballs'
    }
}

food_item = {
    'food item name' : 'Create Your Own 10" Pizza',
    'food item description' : '10" Pizza with Unlimited Toppings!',
    'food item price' : '17.99',
    'food item size' : '',
    'food category' : 'Create Your Own Masterpiece',
    'food item options 1' :{
        'Addon Category Name' : 'Pick Your Studio Crust',
        'Addon Type' : 'Can Select Only One',
        'Addon Items' : {'Traditional'}

    },
    'food item options 2' :{
        'Addon Category Name' : 'Spread Your Sauce',
        'Addon Type' : 'Can Select Mulitple',
        'Addon Items' : { 'Tomato Blend',
                        'Chipotle Tomato Blend',
                        'Smokey BBQ ',
                        'Spicy Buffalo',
                        'Basil Pesto',
                        'Garlic Alfredo', 
                        }

    },
    'food item options 3' :{
        'Addon Category Name' : 'Choose Your Cheese',
        'Addon Type' : 'Can Select Multiple',
        'Addon Items' : {'Freshly Grated Mozzarella',
                        'Extra Mozzarella'}
    },

    'food item options 4' :{
        'Addon Category Name' : 'Load Your Toppings',
        'Addon Type' : 'Can Select Multiple',
        'Addon Items' : {
            'Spinach',
            'Roma Tomatoes',
            'Grape Tomatoes',
            'Black Olives',
            'Green Olives',
            'Sundried Tomatoes',
            'Artichoke',
            'Raw Mushrooms',
            'Roasted Mushrooms',
            'Red Onions',
            'Zucchini',
            'Chipolte Roasted Pineapples',
            'Pineapples',
            'Garlic Roasted Broccoli',
            'Broccoli'
        }

    },
    'food item options 5' :{
        'Addon Category Name' : 'Add Your Protein',
        'Addon Type' : 'Custom',
        'Addon Items' : {'Buffalo chicken',
            'Grilled Chicken',
            'Chorizo Sausage'
            }

    },
    'food item options 6' :{
        'Addon Category Name' : 'Specialty Toppings',
        'Addon Type' : 'Can Select Only One',
        'Addon Items' : {
            'Plant Based Chicken',
            }

    }
    
}

# %%
print(len(addon_cateogry))
# Out:
# 6

# %%
food_categories = [
    {
    'Category Name' : 'Buy 1 Get 1 Free',
    'Category Desc' : ''
    },
    {
        'Category Name' : 'Chef Favorites',
     'Category Desc' : ''
     },
    {
        'Category Name' : 'Picked For You',
     'Category Desc' : ''
     },
    {
    'Category Name' : 'Create Your Own Masterpiece',
     'Category Desc' : ''}
]

# %%
def food_category(food_categories):
    print('Food Category================')


    for category_data in food_categories:
        category_name = category_data['Category Name']
        category_desc = category_data['Category Desc']

        print('Category Name: ', category_name)
        print('Category Desc: ', category_desc)

# %%
food_category(food_categories)
# Out:
# Food Category================
# Category Name:  Buy 1 Get 1 Free
# Category Desc:
# Category Name:  Chef Favorites
# Category Desc:
# Category Name:  Picked For You
# Category Desc:
# Category Name:  Create Your Own Masterpiece
# Category Desc:

# %%
addon_categories = [
    {
        'Category Name': 'Pick Your Studio Crust',
        'Category Desc': ''
    },
    {
        'Category Name': 'Spread Your Sauce',
        'Category Desc': ''
    },
    {
        'Category Name': 'Choose Your Cheese',
        'Category Desc': ''
    },
    {
        'Category Name': 'Load Your Toppings',
        'Category Desc': ''
    },
    {
        'Category Name': 'Add Your Protein',
        'Category Desc': ''
    },
    {
        'Category Name': 'Specialty Toppings',
        'Category Desc': ''
    }
]

# %%
def addon_category(addon_categories):
    print('Addon Category==================')

    for addon_category in addon_categories:
       
        
        category_name = addon_category['Category Name']
        category_desc = addon_category['Category Desc']
        print('Category Name: ', category_name)
        print('Category Desc: ', category_desc)
        

    print("---------Addon Category Successful")

# %%
addon_category(addon_categories)
# Out:
# Addon Category==================
# Category Name:  Pick Your Studio Crust
# Category Desc:
# Category Name:  Spread Your Sauce
# Category Desc:
# Category Name:  Choose Your Cheese
# Category Desc:
# Category Name:  Load Your Toppings
# Category Desc:
# Category Name:  Add Your Protein
# Category Desc:
# Category Name:  Specialty Toppings
# Category Desc:
# ---------Addon Category Successful

# %%
addon_item_value = {
    'Addon Category Name' : 'Pick Your Studio Crust',
    'Addon Items' : {'Traditional',
    'Firecracker',
    'Gluten Free Crust',
    'Cauliflower Crust (GF)',
    'Whoel Grain & Flax Seed',
    'Rosemary Herb Crust'
    }
}
def create_addon_items(addon_item_value):
    addon_category_name = addon_item_value['Addon Category Name']
    addon_items = addon_item_value['Addon Items']


    for addon_item in addon_items:
         # You can provide a description if needed
        print('Addon Category Name: ', addon_category_name)
        print({'Addon item': addon_item})

# %%
create_addon_items(addon_item_value)
# Out:
# Addon Category Name:  Pick Your Studio Crust
# {'Addon item': 'Cauliflower Crust (GF)'}
# Addon Category Name:  Pick Your Studio Crust
# {'Addon item': 'Whoel Grain & Flax Seed'}
# Addon Category Name:  Pick Your Studio Crust
# {'Addon item': 'Rosemary Herb Crust'}
# Addon Category Name:  Pick Your Studio Crust
# {'Addon item': 'Gluten Free Crust'}
# Addon Category Name:  Pick Your Studio Crust
# {'Addon item': 'Firecracker'}
# Addon Category Name:  Pick Your Studio Crust
# {'Addon item': 'Traditional'}
